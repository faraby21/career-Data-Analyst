# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv ('Tingkat Pengangguran Terbuka Berdasarkan Tingkat Pendidikan, 2025.csv')

# %%
df.head()

# %%
df.plot(kind= 'bar', x= 'Tingkat Pendidikan 2', y= 'Unnamed: 1')
plt.title('Tingkat Pengangguran 2025')
plt.xlabel('Tingkat Pendidikan')
plt.ylabel('Persentase')
plt.show()

# %%
print(df.columns.tolist())

# %%
df['Unnamed: 1'] = df['Unnamed: 1'].astype(str).str.replace('%', '').str.replace
df['Unnamed: 1'] = pd.to_numeric(df['Unnamed: 1'], errors='coerce')

# %%
df.plot(kind= 'bar', x= 'Tingkat Pendidikan 2', y= 'Unnamed: 1')
plt.title('Tingkat Pengangguran 2025')
plt.xlabel('Tingkat Pendidikan')
plt.ylabel('Persentase')
plt.show()

# %%
print(df.head(10))

# %%
df = df.dropna(subset=['Tingkat Pendidikan 2'])
print(df.head(10))

# %%
df_baru = pd.read_csv('Tingkat Pengangguran Terbuka Berdasarkan Tingkat Pendidikan, 2025.csv')

# %%
df.head(10)

# %%
with open('Tingkat Pengangguran Terbuka Berdasarkan Tingkat Pendidikan, 2025.csv') as file:
    for i in range(5):
        print(file.readline())

# %%
df_bersih = pd.read_csv(
    'Tingkat Pengangguran Terbuka Berdasarkan Tingkat Pendidikan, 2025.csv', 
    skiprows=3, names=['Tingkat Pendidikan' , 'Persentase'],
    encoding='utf-8-sig')

print(df_bersih)

# %%
plt.figure(figsize=(15, 10))

ax = plt.gca()
df_bersih.plot(kind='bar', x='Tingkat Pendidikan', y='Persentase', ax=ax, color='#0077B6', edgecolor= 'Black')
plt.title('Tingkat Pengangguran Terbuka Berdasarkan Pendidikan (2025)',fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Tingkat Pendidikan', fontsize=12 )
plt.ylabel('Persentase (%)', fontsize=12)
plt.xticks(rotation=30, ha='right', fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 10))

ax = plt.gca()
df_bersih.plot(kind='line', x='Tingkat Pendidikan', y='Persentase', ax=ax, color='#0077B6', linewidth=2, markersize=8)
plt.title('Tren Pengangguran Terbuka Berdasarkan Pendidikan (2025)',fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Tingkat Pendidikan', fontsize=12 )
plt.ylabel('Persentase (%)', fontsize=12)
plt.xticks(rotation=30, ha='right', fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_bersih = pd.read_csv(
    'Tingkat Pengangguran Terbuka Berdasarkan Tingkat Pendidikan, 2025.csv',
    skiprows=3,
    names=['Tingkat Pendidikan', 'Persentase'],
    encoding='utf-8-sig'
)

plt.figure(figsize=(15, 10))

plt.pie( df_bersih['Persentase'], 
    labels=df_bersih['Tingkat Pendidikan'], 
    autopct='%1.1f%%', 
    startangle=140, 
    colors=['#0077B6', '#0096C7', '#03045E', '#90E0EF', '#00b4d8', '#caf0f8'],
    textprops={'fontsize': 11})

plt.title('Proporsi Tingkat  Pendidikan') 
plt.tight_layout()
plt.show()

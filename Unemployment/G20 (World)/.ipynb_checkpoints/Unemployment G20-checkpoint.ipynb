# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df_main = pd.read_csv('API_SL.UEM.TOTL.ZS_DS2_en_csv_v2_33398.csv', skiprows=4)
df_country = pd.read_csv('Metadata_Country_API_SL.UEM.TOTL.ZS_DS2_en_csv_v2_33398.csv')
df_indicator = pd.read_csv('Metadata_Indicator_API_SL.UEM.TOTL.ZS_DS2_en_csv_v2_33398.csv')

# %%
df_main.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 1  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 2  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 3  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
# 4  Unemployment, total (% of total labor force) (...  SL.UEM.TOTL.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2017       2018       2019  \
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   7.214915   7.244843   7.459106
# 2   NaN   NaN   NaN   NaN   NaN  ...  11.184000  11.192000  11.187000
# 3   NaN   NaN   NaN   NaN   NaN  ...   4.284646   4.336100   4.393903
# 4   NaN   NaN   NaN   NaN   NaN  ...  16.617000  16.602000  16.497000
#
#         2020       2021       2022       2023       2024       2025  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1   7.974302   8.407412   7.869470   7.676548   7.571697   7.539233
# 2  11.710000  12.006000  14.100000  14.008000  13.687000  13.351000
# 3   4.799306   4.670761   3.596538   3.203355   3.174915   3.192973
# 4  16.696000  15.799000  14.124000  14.051000  14.020000  14.108000
#
#    Unnamed: 70
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 71 columns]

# %%
#Data Based On Main factor high rate unemployment

# %%
tahun_cols = [str(year) for year in range(1960, 2023)]

df_long = df_main.melt(
    id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'],
    value_vars=tahun_cols,
    var_name='Year',
    value_name='Unemployment_Rate'
)


df_long['Year'] = pd.to_numeric(df_long['Year'])

list_Country = ['IDN', 'MYS', 'SGP', 'THAI', 'LAO', 'VNM', 'PHL', 'KHM']
df_SoutheastAsia_Country = df_long[df_long['Country Code'].isin(list_Country)]

plt.figure(figsize=(12, 6))
sns.lineplot(
    data=df_SoutheastAsia_Country, 
    x='Year', 
    y='Unemployment_Rate', 
    hue='Country Name', 
    marker='o'
)


plt.title('Comparison of Unemployment Rates Across Several Countries', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Unemployment Rate (%)', fontsize=12)
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#Diagram Based On High Rate Unemployment On South East Asia

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_long['Year'] = pd.to_numeric(df_long['Year'])


list_negara = ['IDN', 'MYS', 'SGP', 'THAI', 'LAO', 'VNM', 'PHL', 'KHM']


df_bandingan = df_long[
    (df_long['Year'] >= 2020) & 
    (df_long['Year'] <= 2025) & 
    (df_long['Country Code'].isin(list_negara))
]

plt.figure(figsize=(12, 6))
sns.lineplot(
    data=df_bandingan, 
    x='Year', 
    y='Unemployment_Rate', 
    hue='Country Name', 
    marker='o', 
    linewidth=2.5
)

# 5. Pengaturan Tampilan Grafik
plt.title('Compare Unemployment Rate In South East Asia (2020 - 2025)', fontsize=14, fontweight='bold')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Unemployment Rate (%)', fontsize=12)
plt.xticks(range(2020, 2026)) # Memastikan sumbu X menampilkan tahun secara utuh dari 2020-2025
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#Diagram Based On High risk Unemployment in digitalitaion era on south east asia

# %%
import matplotlib.pyplot as plt
import seaborn as sns

lastly_year = '2024'
df_2024 = df_long[df_long['Year'] == 2024].dropna(subset=['Unemployment_Rate'])
df_2024 = df_2024[df_2024['Unemployment_Rate'] > 0] 


top_5_country = df_2024.sort_values(by='Unemployment_Rate', ascending=False).head(5)


print(top_5_country[['Country Name', 'Unemployment_Rate']])

plt.figure(figsize=(10, 5))
sns.barplot(data=top_5_country, x='Unemployment_Rate', y='Country Name', palette='viridis')
plt.title('5 Country with highest rate unemployment (2024)')
plt.xlabel('Unemployment Rate (%)')
plt.show()
# Out:
# Empty DataFrame
# Columns: [Country Name, Unemployment_Rate]
# Index: []

# %%
tahun_cols = [str(year) for year in range(1960, 2023)]

df_long = df_main.melt(
    id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'],
    value_vars=tahun_cols,
    var_name='Year',
    value_name='Unemployment_Rate'
)


df_long['Year'] = pd.to_numeric(df_long['Year'])

list_Country = ['SWZ', 'ZAF', 'DJI', 'BWA', 'GAB']
df_SoutheastAsia_Country = df_long[df_long['Country Code'].isin(list_Country)]

plt.figure(figsize=(12, 6))
sns.lineplot(
    data=df_SoutheastAsia_Country, 
    x='Year', 
    y='Unemployment_Rate', 
    hue='Country Name', 
    marker='o'
)


plt.title('Comparison of Unemployment Rates Across Several Countries', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Unemployment Rate (%)', fontsize=12)
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#Diagram Based On high rate unemployment iin top 5 G20

# %%
"""
Statement South East Asian who have high rate unemployment: In south east asia, Indonesian has high rate with unemployment on 2009 until 2010. 
statememt south East Asian  when digital era easy to find job: When Digitalisitation, Malaysia has high rate with unemployment on 2021 until 2022.
Statment Top 5 country in G20 who have high rate unemployment: In africa, they have crisism with employee.
Statement Top 5 country when digital era easy to find job: When Digitalitation Era, Africa still have crisism employee.
"""

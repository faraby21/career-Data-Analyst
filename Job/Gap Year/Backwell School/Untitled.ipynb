# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('5841C0E09401FBC5CA5F464A8056DA40.csv', encoding='ISO-8859-1', engine='python', on_bad_lines='skip')
df.head()

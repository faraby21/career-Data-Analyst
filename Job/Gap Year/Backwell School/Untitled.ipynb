# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Backwell(GapYear).csv')
df.head()
# Out:
#                                           Unnamed: 0  \
# 0  Paid work in agriculture,horses,hospitality,te...
# 1                                                NaN
# 2                                       01865-861516
# 3                                                NaN
# 4                                    www.visitoz.org
#
#                                           Unnamed: 1  \
# 0  We train you as waiting and bar staff to work ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                            www.atyourservice.co.uk
#
#                                           Unnamed: 2  \
# 0  Paid work opportunities at children's activity...
# 1                                                NaN
# 2                                        403-762-537
# 3                                                NaN
# ...

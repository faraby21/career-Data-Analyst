# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_2017 = pd.read_csv ('table-6-2017-18.csv')
df_2017.head()
# Out:
# C:\Users\farab\AppData\Local\Temp\ipykernel_24752\3122574376.py:1: DtypeWarning: Columns (0,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2017 = pd.read_csv ('table-6-2017-18.csv')
#               Title  \
# 0          Location
# 1    Academic years
# 2       Data source
# 3      Sourced from
# 4  Data source link
#
#   Graduate activities by provider, country of provider, permanent address, level of qualification obtained, mode of former study, interim study and academic year  \
# 0                                                 UK
# 1                                            2017/18
# 2                               HESA / OfS / DfE(NI)
# 3                Detailed tables (Graduate Outcomes)
# 4  https://www.hesa.ac.uk/data-and-analysis/gradu...
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0        NaN        NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN
# 2        NaN        NaN         NaN         NaN
# 3        NaN        NaN         NaN         NaN
# 4        NaN        NaN         NaN         NaN

# %%
df_2017 = pd.read_csv ('table-6-2017-18.csv', skiprows=8)
df_2017.head()
# Out:
# C:\Users\farab\AppData\Local\Temp\ipykernel_24752\2420214684.py:1: DtypeWarning: Columns (0,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2017 = pd.read_csv ('table-6-2017-18.csv', skiprows=8)
#              Code page                                      Unicode UTF-8  \
# 0           Disclaimer  Please note that this data includes rounded to...
# 1  Table 2017/18 total                                             769195
# 2         Last updated                                             Jun-26
# 3                  NaN                                                NaN
# 4                UKPRN                                      Provider name
#
#             Unnamed: 2         Unnamed: 3                       Unnamed: 4  \
# 0                  NaN                NaN                              NaN
# 1                  NaN                NaN                              NaN
# 2                  NaN                NaN                              NaN
# 3                  NaN                NaN                              NaN
# 4  Country of provider  Permanent address  Level of qualification obtained
#
#              Unnamed: 5     Unnamed: 6 Unnamed: 7     Unnamed: 8 Unnamed: 9  \
# 0                   NaN            NaN        NaN            NaN        NaN
# 1                   NaN            NaN        NaN            NaN        NaN
# 2                   NaN            NaN        NaN            NaN        NaN
# 3                   NaN            NaN        NaN            NaN        NaN
# 4  Mode of former study  Interim study   Activity  Academic year     Number
#
#   Unnamed: 10              Unnamed: 11
# 0         NaN                      NaN
# 1         NaN                      NaN
# 2         NaN                      NaN
# 3         NaN                      NaN
# 4     Percent  95% confidence interval

# %%
df_2017 = pd.read_csv ('table-6-2017-18.csv', skiprows=13)
df_2017.head()
# Out:
#         UKPRN              Provider name Country of provider  \
# 0  10008071.0  AA School of Architecture                 All
# 1  10008071.0  AA School of Architecture                 All
# 2  10008071.0  AA School of Architecture                 All
# 3  10008071.0  AA School of Architecture                 All
# 4  10008071.0  AA School of Architecture                 All
#
#   Permanent address Level of qualification obtained Mode of former study  \
# 0               All                             All                  All
# 1               All                             All                  All
# 2               All                             All                  All
# 3               All                             All                  All
# 4               All                             All                  All
#
#                        Interim study  \
# 0  Exclude significant interim study
# 1  Exclude significant interim study
# 2  Exclude significant interim study
# 3  Exclude significant interim study
# 4  Exclude significant interim study
#
#                                             Activity Academic year  Number  \
# 0                       Employment and further study       2017/18      15
# 1                               Full-time employment       2017/18      90
# 2                            Full-time further study       2017/18       0
# 3                                    Non-respondents       2017/18      85
# 4  Other including travel, caring for someone or ...       2017/18       5
#
#   Percent 95% confidence interval
# 0     12%                (6%-22%)
# 1     67%               (55%-77%)
# 2      1%                 (0%-7%)
# 3     NaN                     NaN
# 4      2%                 (1%-9%)

# %%
print(df_2017['Activity'].unique())

df_other_activities = df_2017[df_2017['Activity'] == 'Non-respondents']
df_other_activities.head()
# Out:
# ['Employment and further study' 'Full-time employment'
#  'Full-time further study' 'Non-respondents'
#  'Other including travel, caring for someone or retired'
#  'Part-time employment' 'Part-time further study' 'Total'
#  'Total with known outcomes' 'Unemployed' 'Unknown pattern of employment'
#  'Unknown pattern of further study' 'Voluntary or unpaid work']
#          UKPRN              Provider name Country of provider  \
# 3   10008071.0  AA School of Architecture                 All
# 16  10008071.0  AA School of Architecture                 All
# 29  10008071.0  AA School of Architecture                 All
# 42  10008071.0  AA School of Architecture                 All
# 55  10008071.0  AA School of Architecture                 All
#
#    Permanent address Level of qualification obtained Mode of former study  \
# 3                All                             All                  All
# 16               All                             All                  All
# 29               All                             All            Full-time
# 42               All                             All            Full-time
# 55               All                    Postgraduate                  All
#
#                         Interim study         Activity Academic year  Number  \
# 3   Exclude significant interim study  Non-respondents       2017/18      85
# 16  Include significant interim study  Non-respondents       2017/18      85
# 29  Exclude significant interim study  Non-respondents       2017/18      85
# 42  Include significant interim study  Non-respondents       2017/18      85
# 55  Exclude significant interim study  Non-respondents       2017/18      60
#
#    Percent 95% confidence interval
# 3      NaN                     NaN
# 16     NaN                     NaN
# 29     NaN                     NaN
# 42     NaN                     NaN
# 55     NaN                     NaN

# %%
"""
EDA is Failure In this case because doesnt have correlation 
"""
